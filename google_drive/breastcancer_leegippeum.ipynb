# %% [markdown]
# # breast cancer

# %% [markdown]
# keys : 'data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'

# %% [markdown]
# mean, median, std, var, min, max

# %%
import numpy as np
from sklearn import datasets

# %%
data = datasets.load_breast_cancer()

# %%
type(data)
# Out:
# sklearn.utils.Bunch

# %%
data

# %%
len(data)
# Out:
# 6

# %%
data.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %% [markdown]
# # key_DESCR

# %% [markdown]
# 유방암 진단 데이터\
# 환자의 수: 569\
# 속성의 수 : 30

# %%
print(data['DESCR'])

# %% [markdown]
# # key_data

# %% [markdown]
# attributes(30):\
# radius, texture, perimeter, area, smoothness, compactness, concavity, concave points, symmetry, fractal dimension, radius, texture, perimeter, area, smoothness, compactness, concavity, concave points, symmetry, radius, texture, perimeter, area, smoothness, compactness, concavity, concave points, symmetry, fractal dimension

# %%
print(data['data'])

# %%
data['data']

# %%
len(data['data'])
# Out:
# 569

# %%
breast_cancer = data['data']

# %%
np.shape(data['data'])
# Out:
# (569, 30)

# %%
for i in range(len(breast_cancer)):
    mean = np.mean(breast_cancer[:,i])
    median = np.mean(breast_cancer[:,i])
    std = np.mean(breast_cancer[:,i])
    var = np.mean(breast_cancer[:,i])
    min = np.mean(breast_cancer[:,i])
    max = np.mean(breast_cancer[:,i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-772433f2b1c6> in <module>()
#       1 for i in range(len(breast_cancer)):
# ----> 2     mean_radius = np.mean(breast_cancer[:,i])
#       3     median_radius = np.mean(breast_cancer[:,i])
#       4     std_radius = np.mean(breast_cancer[:,i])
#       5     var_radius = np.mean(breast_cancer[:,i])
#
# IndexError: index 30 is out of bounds for axis 1 with size 30

# %%
attribute = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concavepoints_mean', 'symmetry_mean', 'fractaldimension_mean',
             'radius_standarderror', 'texture_standarderror', 'perimeter_standarderror', 'area_standarderror', 'smoothness_standarderror', 'compactness_standarderror', 'concavity_standarderror', 'concavepoints_standarderror', 'symmetry_standarderror', 'fractaldimension_standarderror',
             'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concavepoints_worst', 'symmetry_worst', 'fractaldimension_worst']
attribute

attribute = np.array(attribute)
attribute
# Out:
# array(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concavepoints_mean', 'symmetry_mean', 'fractaldimension_mean',
#        'radius_standarderror', 'texture_standarderror',
#        'perimeter_standarderror', 'area_standarderror',
#        'smoothness_standarderror', 'compactness_standarderror',
#        'concavity_standarderror', 'concavepoints_standarderror',
#        'symmetry_standarderror', 'fractaldimension_standarderror',
#        'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst',
#        'smoothness_worst', 'compactness_worst', 'concavity_worst',
#        'concavepoints_worst', 'symmetry_worst', 'fractaldimension_worst'],
#       dtype='<U30')

# %%
########

for i in range(len(attribute)):
    attribute[:,i] = [np.mean(breast_cancer[:,i], axis=1), np.median(breast_cancer[:,i], axis=1), np.std(breast_cancer[:,i], axis=1), np.var(breast_cancer[:,i], axis=1), np.min(breast_cancer[:,i], axis=1), np.max(breast_cancer[:,i], axis=1)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-44-51aacae24088> in <module>()
#       1
#       2 for i in range(len(attribute)):
# ----> 3     attribute[:,i] = [np.mean(breast_cancer[:,i], axis=1), np.median(breast_cancer[:,i], axis=1), np.std(breast_cancer[:,i], axis=1), np.var(breast_cancer[:,i], axis=1), np.min(breast_cancer[:,i], axis=1), np.max(breast_cancer[:,i], axis=1)]
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3333
#    3334     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 3335                           out=out, **kwargs)
#    3336
#    3337
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#     136
#     137     is_float16_result = False
# ...

# %%
for i in :
  
for i in :
    attribute[i]= [mean[i], median[i], std[i], var[i], min[i], max[i]]

# %%
# 1번째 속성, radius
# mean, median, std, var, min, max

mean_radius = np.mean(breast_cancer[:,0])
median_radius = np.median(breast_cancer[:,0])
std_radius = np.std(breast_cancer[:,0])
var_radius = np.var(breast_cancer[:,0])
min_radius = np.min(breast_cancer[:,0])
max_radius = np.max(breast_cancer[:,0])

# %%
# 2번째 속성, texture
# mean, median, std, var, min, max

mean_texture = np.mean(breast_cancer[:,1])
median_texture = np.median(breast_cancer[:,1])
std_texture = np.std(breast_cancer[:,1])
var_texture = np.var(breast_cancer[:,1])
min_texture = np.min(breast_cancer[:,1])
max_texture = np.max(breast_cancer[:,1])

# %%
# 3번째 속성, perimeter
# mean, median, std, var, min, max

mean_perimeter = np.mean(breast_cancer[:,2])
median_perimeter = np.median(breast_cancer[:,2])
std_perimeter = np.std(breast_cancer[:,2])
var_perimeter = np.var(breast_cancer[:,2])
min_perimeter = np.min(breast_cancer[:,2])
max_perimeter = np.max(breast_cancer[:,2])

# %%
# 4번째 속성, area
# mean, median, std, var, min, max

mean_area = np.mean(breast_cancer[:,3])
median_area = np.median(breast_cancer[:,3])
std_area = np.std(breast_cancer[:,3])
var_area = np.var(breast_cancer[:,3])
min_area = np.min(breast_cancer[:,3])
max_area = np.max(breast_cancer[:,3])

# %%
# 5번째 속성, smoothness
# mean, median, std, var, min, max

mean_smoothness = np.mean(breast_cancer[:,4])
median_smoothness = np.median(breast_cancer[:,4])
std_smoothness = np.std(breast_cancer[:,4])
var_smoothness = np.var(breast_cancer[:,4])
min_smoothness = np.min(breast_cancer[:,4])
max_smoothness = np.max(breast_cancer[:,4])

# %%
# 6번째 속성, compactness
# mean, median, std, var, min, max

mean_compactness = np.mean(breast_cancer[:,5])
median_compactness = np.median(breast_cancer[:,5])
std_compactness = np.std(breast_cancer[:,5])
var_compactness = np.var(breast_cancer[:,5])
min_compactness = np.min(breast_cancer[:,5])
max_compactness = np.max(breast_cancer[:,5])

# %%
# 7번째 속성, concavity
# mean, median, std, var, min, max

mean_concavity = np.mean(breast_cancer[:,2])
median_concavity = np.median(breast_cancer[:,2])
std_concavity = np.std(breast_cancer[:,2])
var_concavity = np.var(breast_cancer[:,2])
min_concavity = np.min(breast_cancer[:,2])
max_concavity = np.max(breast_cancer[:,2])

# %%
# 8번째 속성, perimeter
# mean, median, std, var, min, max

mean_perimeter = np.mean(breast_cancer[:,2])
median_perimeter = np.median(breast_cancer[:,2])
std_perimeter = np.std(breast_cancer[:,2])
var_perimeter = np.var(breast_cancer[:,2])
min_perimeter = np.min(breast_cancer[:,2])
max_perimeter = np.max(breast_cancer[:,2])

# %%
# 8번째 속성, perimeter
# mean, median, std, var, min, max

mean_perimeter = np.mean(breast_cancer[:,2])
median_perimeter = np.median(breast_cancer[:,2])
std_perimeter = np.std(breast_cancer[:,2])
var_perimeter = np.var(breast_cancer[:,2])
min_perimeter = np.min(breast_cancer[:,2])
max_perimeter = np.max(breast_cancer[:,2])

# %%
# 8번째 속성, perimeter
# mean, median, std, var, min, max

mean_perimeter = np.mean(breast_cancer[:,2])
median_perimeter = np.median(breast_cancer[:,2])
std_perimeter = np.std(breast_cancer[:,2])
var_perimeter = np.var(breast_cancer[:,2])
min_perimeter = np.min(breast_cancer[:,2])
max_perimeter = np.max(breast_cancer[:,2])

# %% [markdown]
# # key_freature_names

# %%
print(data['feature_names'])

# %% [markdown]
# # key_filename

# %%
print(data['filename'])

# %% [markdown]
# # key_target

# %%
print(data['target'])

# %% [markdown]
# # key_target_names

# %%
print(data['target_names'])

# %%
# sepal length, sepal width, petal length, petal width의 각 각의 mean, median, std, var, min, max 구하기

# %%
# data에서 같은 리스트로 묶인 [sepal length, sepal width, petal length, petal width]의 값들을 
# sepal length의 값들로만 이루어진 리스트와 같이 각각 나누어 리스트로 묶어줌.

sepal_length = data[:,0]
sepal_width = data[:,1]
petal_length = data[:,2]
petal_width = data[:,3]

# %%
# sepal length, sepal width, petal length, petal width의 각각의 mean, median, std, var, min, max를 구하기

# %%
# mean

mean_sepal_length = np.mean(sepal_length[:,], axis = 0)
mean_sepal_width = np.mean(sepal_width[:,], axis = 0)
mean_petal_length = np.mean(petal_length[:,], axis = 0)
mean_petal_width = np.mean(petal_width[:,], axis = 0)

# %%
# median

median_sepal_length = np.median(sepal_length[:,], axis = 0)
median_sepal_width = np.median(sepal_width[:,], axis = 0)
median_petal_length = np.median(petal_length[:,], axis = 0)
median_petal_width = np.median(petal_width[:,], axis = 0)

# %%
# std

std_sepal_length = np.std(sepal_length[:,], axis = 0)
std_sepal_width = np.std(sepal_width[:,], axis = 0)
std_petal_length = np.std(petal_length[:,], axis = 0)
std_petal_width = np.std(petal_width[:,], axis = 0)

# %%
# var

var_sepal_length = np.var(sepal_length[:,], axis = 0)
var_sepal_width = np.var(sepal_width[:,], axis = 0)
var_petal_length = np.var(petal_length[:,], axis = 0)
var_petal_width = np.var(petal_width[:,], axis = 0)

# %%
# min

min_sepal_length = np.min(sepal_length[:,], axis = 0)
min_sepal_width = np.min(sepal_width[:,], axis = 0)
min_petal_length = np.min(petal_length[:,], axis = 0)
min_petal_width = np.min(petal_width[:,], axis = 0)

# %%
# max

max_sepal_length = np.max(sepal_length[:,], axis = 0)
max_sepal_width = np.max(sepal_width[:,], axis = 0)
max_petal_length = np.max(petal_length[:,], axis = 0)
max_petal_width = np.max(petal_width[:,], axis = 0)

# %%
# mean, median, std, var, min, max 순서

len_sepal = mean_sepal_length, median_sepal_length, std_sepal_length, var_sepal_length, min_sepal_length, max_sepal_length
wid_sepal = mean_sepal_width, median_sepal_width, std_sepal_width, var_sepal_width, min_sepal_width, max_sepal_width
len_petal = mean_petal_length, median_petal_length, std_petal_length, var_petal_length, min_petal_length, max_petal_length
wid_sepal = mean_petal_width, median_petal_width, std_petal_width, var_petal_width, min_petal_width, max_petal_width


len_sepal, wid_sepal, len_petal, wid_sepal
# Out:
# ((5.843333333333334, 5.8, 0.8253012917851409, 0.6811222222222223, 4.3, 7.9),
#  (1.1993333333333336, 1.3, 0.7596926279021594, 0.5771328888888888, 0.1, 2.5),
#  (3.7580000000000005, 4.35, 1.759404065775303, 3.0955026666666665, 1.0, 6.9),
#  (1.1993333333333336, 1.3, 0.7596926279021594, 0.5771328888888888, 0.1, 2.5))
